# %%
import pandas as pd

file_path = "C:\Phone-Pay-Finanacial-Insights-Dashboard\Phonepe-Final-Dataset.xlsx"
df = pd.read_excel(file_path)

df.head(20)
# Out:
#       User_ID                 Name  Age  Join_Date
# 0   PP0000001         Holly Rivera   56 2025-06-17
# 1   PP0000002          Kevin Lopez   46 2023-12-10
# 2   PP0000003      Douglas Roberts   32 2024-09-14
# 3   PP0000004        Walter Davila   60 2023-10-19
# 4   PP0000005          Grace Blake   25 2025-03-10
# 5   PP0000006      Nicholas Adkins   38 2024-09-08
# 6   PP0000007       James Campbell   56 2023-09-10
# 7   PP0000008         Melissa Hall   36 2023-12-26
# 8   PP0000009    Robert Williamson   40 2025-02-11
# 9   PP0000010         James Golden   28 2025-01-23
# 10  PP0000011       Jonathon Brock   28 2023-11-18
# 11  PP0000012         James Cuevas   41 2024-01-31
# 12  PP0000013        Kevin Gardner   53 2023-08-08
# 13  PP0000014         Robert Jones   57 2025-02-17
# 14  PP0000015     Samantha Garrett   41 2024-06-04
# 15  PP0000016          Joshua Barr   20 2023-10-29
# 16  PP0000017         Maurice Hale   39 2024-05-24
# 17  PP0000018          Stacey Ward   19 2025-04-14
# 18  PP0000019            Sean Wood   41 2025-04-19
# 19  PP0000021  Alexandria Mccarthy   55 2024-10-31

# %%
df.shape
# Out:
# (107658, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107658 entries, 0 to 107657
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   User_ID    107658 non-null  object
#  1   Name       107658 non-null  object
#  2   Age        107658 non-null  int64
#  3   Join_Date  107658 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 3.3+ MB

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
df.columns
# Out:
# Index(['user_id', 'name', 'age', 'join_date'], dtype='object')

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# user_id      0
# name         0
# age          0
# join_date    0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull(), cbar=False)
plt.show()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                  age                      join_date
# count  107658.000000                         107658
# mean       39.034628  2024-08-01 05:09:42.845678336
# min        18.000000            2023-08-03 00:00:00
# 25%        28.000000            2024-02-01 00:00:00
# 50%        39.000000            2024-08-01 00:00:00
# 75%        50.000000            2025-01-30 00:00:00
# max        60.000000            2025-08-02 00:00:00
# std        12.382832                            NaN

# %%
for col in df.select_dtypes(include="object").columns:
    print(f"\n{col}")
    print(df[col].nunique())
# Out:
# user_id
# 107658
#
# name
# 75254
